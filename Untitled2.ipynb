# %%
import matplotlib.pyplot as plt
import pandas as pd
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
def word_cloud(wd_list):
    stopwords = set(STOPWORDS)
    all_words = ' '.join([text for text in wd_list])
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stopwords,
        width=1600,
        height=800,
        random_state=1,
        colormap='jet',
        max_words=80,
        max_font_size=200).generate(all_words)
    plt.figure(figsize=(12, 10))
    plt.axis('off')
    plt.imshow(wordcloud, interpolation="bilinear");

cancer = pd.read_csv("C:/Users/shong3/data_project/ZodiacSentiment/json_files/firstAPIcall/cancer.csv")

word_cloud(cancer['text'])

# %%
cancer
# Out:
#     Unnamed: 0                                               text  \
# 0            0  You might receive some shocking news from a fr...
# 1            1  You might receive some shocking news from a fr...
# 2            2  You might receive some shocking news from a fr...
# 3            3  You might receive some shocking news from a fr...
# 4            4  You might receive some shocking news from a fr...
# ..         ...                                                ...
# 95          95  @soulsinginguy Dude, I very rarely go to Twitt...
# 96          96  RT @CancerTerms: Make a wish near a #Cancer th...
# 97          97  @saintilyass atleast rising, my youngest siste...
# 98          98  i should've muted this tweet my god \n\nalso i...
# 99          99  RT @Harryslaststand: I think of him everyday. ...
#
#               user  retweets  favorites                        datetime
# 0         Flyty___         0          0  Sat Nov 07 21:00:09 +0000 2020
# 1       squeeakers         0          0  Sat Nov 07 21:00:09 +0000 2020
# 2     favour_favzs         0          0  Sat Nov 07 21:00:09 +0000 2020
# 3       sabebelove         0          0  Sat Nov 07 21:00:09 +0000 2020
# 4     alexussntigo         0          0  Sat Nov 07 21:00:09 +0000 2020
# ..             ...       ...        ...                             ...
# 95     BlowerBrant         0          0  Sat Nov 07 20:59:50 +0000 2020
# 96     rphl_lczndr       126          0  Sat Nov 07 20:59:50 +0000 2020
# 97         ghlouyh         0          0  Sat Nov 07 20:59:49 +0000 2020
# 98         trawbe1         0          0  Sat Nov 07 20:59:49 +0000 2020
# 99  johnatkinson80         4          0  Sat Nov 07 20:59:48 +0000 2020
#
# [100 rows x 6 columns]
